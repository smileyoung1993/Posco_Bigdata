# %%
import pandas as pd
import numpy as np
#sklearn.preprocessing 의 scale:스케일 조정 패키지
from sklearn.preprocessing import scale
from sklearn.ensemble import GradientBoostingClassifier
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.font_manager as fm
from sklearn.model_selection import train_test_split
for f in fm.fontManager.ttflist:
    if 'NanumBarunGothic' in f.fname:
        plt.rcParams['font.family'] = 'NanumBarunGothic' # 폰트를 나눔고딕으로
print(plt.rcParams['font.family'])
matplotlib.rcParams['axes.unicode_minus'] = False #'-'기호 제대로 나오게함
# Out:
# ['NanumBarunGothic']

# %%
df_custom = pd.read_csv("../data/callcustom.csv",encoding = 'euc-kr')
df_custom.head()
# Out:
#     CHURN CUSTOMER_ID GENDER  AGE CHARGE_TYPE  HANDSET USAGE_BAND  \
# 0  Active     K102990      F   31     CAT 100  ASAD170        Med
# 1  Active     K103280      M   27     CAT 100      S50        Med
# 2  Active     K103660      M   27     CAT 100  ASAD170        Med
# 3  Active     K103730      M   61     CAT 100  ASAD170        Med
# 4  Active     K104560      F   52     CAT 100      S50        Med
#
#    SERVICE_DURATION  DROPPED_CALLS  PEAK_CALLS_NO  PEAK_CALLS_TIME  \
# 0             33.33              6            218            379.8
# 1             30.87             10            373            656.4
# 2             49.40             11            260            582.0
# 3             48.60              1            294            661.8
# 4             56.03              0            221            555.6
#
#    WEEKEND_CALLS_NO  WEEKEND_CALLS_TIME  TOTAL_CALLS_NO  TOTAL_CALLS_TIME
# 0                 9                21.6             366             632.4
# 1                11                28.0             411             810.4
# 2                 0                 0.0             265             614.1
# 3                14               101.5             326             844.0
# 4                 7                25.0             274             673.0

# %%
df_custom.CHURN = df_custom.CHURN.map(lambda x:1 if x =="Active" else 0)
df_custom
# Out:
#      CHURN CUSTOMER_ID GENDER  AGE CHARGE_TYPE  HANDSET USAGE_BAND  \
# 0        1     K102990      F   31     CAT 100  ASAD170        Med
# 1        1     K103280      M   27     CAT 100      S50        Med
# 2        1     K103660      M   27     CAT 100  ASAD170        Med
# 3        1     K103730      M   61     CAT 100  ASAD170        Med
# 4        1     K104560      F   52     CAT 100      S50        Med
# 5        1     K105530      M   51     CAT 100      S80        Med
# 6        1     K106210      F   30     CAT 100  ASAD170        Med
# 7        1     K106350      M   36     CAT 100  ASAD170        Med
# 8        1     K106570      F   43     CAT 100      S50        Med
# 9        1     K107570      F   50     CAT 100  ASAD170        Med
# 10       1     K107660      M   52     CAT 100      S80        Med
# 11       1     K107820      F   28     CAT 100      S50        Med
# 12       1     K109810      F   29     CAT 100      S80        Med
# 13       1     K110530      M   52     CAT 100      S80        Med
# 14       1     K110630      F   37     CAT 100      S80        Med
# 15       1     K110700      M   46     CAT 100      S50        Med
# 16       1     K110930      M   60     CAT 200      S50    MedHigh
# 17       1     K110950      F   53     CAT 200      S50       High
# 18       1     K111100      F   46     CAT 200  ASAD170    MedHigh
# 19       1     K111540      F   46     CAT 200      S50    MedHigh
# 20       1     K111680      F   38     CAT 200      S80       High
# 21       1     K111690      M   61     CAT 200  ASAD170    MedHigh
# 22       1     K111750      M   46     CAT 200      S50    MedHigh
# 23       1     K111770      M   27     CAT 200      S50       High
# 24       1     K111920      M   32     CAT 200      S50    MedHigh
# 25       1     K112090      F   26     CAT 200  ASAD170    MedHigh
# 26       1     K112400      M   39     CAT 200      S50    MedHigh
# 27       1     K112700      F   36     CAT 200      S80       High
# 28       1     K112820      M   29     CAT 200      S80    MedHigh
# 29       1     K113150      M   29     CAT 200      S80    MedHigh
# ..     ...         ...    ...  ...         ...      ...        ...
# 900      0     K390310      M   37    Play 300   ASAD90        Med
# 901      0     K396990      M   17     CAT 100    SOP10        Med
# 902      0     K397680      M   19     CAT 100      S50        Med
# 903      0     K399670      F   31     CAT 100    SOP20        Med
# 904      0     K399840      F   33     CAT 100    SOP20        Med
# 905      0     K399850      M   16     CAT 100    SOP20        Med
# 906      0     K400720      M   17     CAT 100    BS110        Med
# 907      0     K400980      F   57     CAT 100    SOP10        Med
# 908      0     K401610      M   23     CAT 200    SOP20        Med
# 909      0     K402650      M   62     CAT 200    SOP20    MedHigh
# 910      0     K402850      F   48     CAT 200    SOP10    MedHigh
# 911      0     K402950      M   71     CAT 200    SOP20        Med
# 912      0     K403070      F   25     CAT 200    SOP10        Med
# 913      0     K403140      M   14     CAT 200    BS110    MedHigh
# 914      0     K404260      M   35     CAT 200      S50    MedHigh
# 915      0     K404370      M   20     CAT 200    BS110    MedHigh
# 916      0     K404470      M   59     CAT 200    SOP20        Med
# 917      0     K404650      M   60     CAT 200      S50    MedHigh
# 918      0     K404830      F   12     CAT 200      S50    MedHigh
# 919      0     K405840      M   16     CAT 200    BS110    MedHigh
# 920      0     K406200      F   27     CAT 200      S50    MedHigh
# 921      0     K406570      M   21     CAT 200    BS110        Med
# 922      0     K406950      M   37     CAT 200    BS110        Med
# 923      0     K409630      F   26     CAT 200    SOP10       High
# 924      0     K412310      F   14    Play 100    SOP20        Med
# 925      0     K413330      M   19    Play 100    SOP10        Med
# 926      0     K413410      F   59    Play 100    SOP20        Med
# 927      0     K415490      F   33    Play 300      S50        Med
# 928      0     K415880      F   25    Play 300      S50        Med
# 929      0     K416650      F   30    Play 300    SOP10        Med
#
#      SERVICE_DURATION  DROPPED_CALLS  PEAK_CALLS_NO  PEAK_CALLS_TIME  \
# 0               33.33              6            218            379.8
# 1               30.87             10            373            656.4
# 2               49.40             11            260            582.0
# 3               48.60              1            294            661.8
# 4               56.03              0            221            555.6
# 5               49.43              3            289            486.6
# 6               32.30              6            427            729.6
# 7               54.87              2            522            801.6
# 8               11.23              0            156            516.6
# 9               49.97              0            136            466.2
# 10              11.00              0             81            682.2
# 11              13.50              0            212            733.2
# 12              51.77              0            114            595.8
# 13              54.70              2             11            672.0
# 14              50.83              2             12            579.6
# 15              29.23              0              3            719.4
# 16              57.53              1            543            933.6
# 17              10.00              0           1168           2376.0
# 18              42.80              8            604           1233.0
# 19              57.10              0            990           1626.0
# 20              51.07              0           1179           1992.6
# 21              10.97              5            789           1545.6
# 22              54.87              0            998           1578.0
# 23              23.33              1            983           1613.4
# 24              36.07              1            835           1443.0
# 25              39.27              0            857           1481.4
# 26              38.67              1            635           1315.8
# 27              29.57              3            573           1625.4
# 28              16.63              9            502           1170.6
# 29              50.97              0            436            793.8
# ..                ...            ...            ...              ...
# 900             23.03              5            166            316.2
# 901             17.67             12            365            582.6
# 902             14.47             15            252            393.0
# 903             41.57             12             77            651.6
# 904             56.90             13             51            484.2
# 905             30.57             14             64            609.6
# 906             52.67             12            141            743.4
# 907             33.53             15            110            613.8
# 908             18.07             13            380            789.6
# 909             10.50             14            843           1328.4
# 910             40.20             13            666           1285.2
# 911             33.10             13            614            954.0
# 912             19.03             14            334            762.6
# 913             21.20             15            499           1147.8
# 914             31.03             14            722           1357.8
# 915             22.80             14            416            811.2
# 916             53.10             12            513            994.2
# 917             53.00             14            544           1413.0
# 918             48.07             15            708           1080.0
# 919             51.47             12            417           1633.2
# 920              9.63             15            302           1201.8
# 921             42.50             14            257            957.6
# 922             47.80             12            163           1181.4
# 923             35.53             13            381           1768.2
# 924             14.37             14            118            199.2
# 925             17.40             12             60            100.8
# 926             17.37             15             82            130.2
# 927             44.93             12            174            286.2
# 928             40.43             14            315            552.0
# 929             31.47             12             16            306.6
#
#      WEEKEND_CALLS_NO  WEEKEND_CALLS_TIME  TOTAL_CALLS_NO  TOTAL_CALLS_TIME
# 0                   9                21.6             366             632.4
# 1                  11                28.0             411             810.4
# 2                   0                 0.0             265             614.1
# 3                  14               101.5             326             844.0
# 4                   7                25.0             274             673.0
# 5                   1                31.8             427             903.3
# 6                  12                52.8             490             907.2
# 7                   0                 0.0             558             884.7
# 8                   8                84.0             362             987.6
# 9                  13                31.8             186             632.7
# 10                 20                58.8             170             943.5
# 11                  0                 0.0             226             798.3
# 12                  0                 0.0             150             720.9
# 13                 12                34.2              23             706.2
# 14                 22                42.0              54             869.1
# 15                 13                20.5             106             933.7
# 16                 11                46.8             686            1445.4
# 17                 11                49.8            1275            2844.0
# 18                 26                40.8             655            1446.9
# 19                  5                49.8            1050            1844.7
# 20                 12                41.4            1203            2055.3
# 21                 34               119.4             900            1812.6
# 22                 37                65.4            1071            1746.9
# 23                  4                82.8            1116            2106.0
# 24                  1                 3.0            1111            1893.0
# 25                 10                38.0             880            1555.1
# 26                  3                56.4             652            1420.5
# 27                  5                20.4             695            2084.4
# 28                  0                 0.0             580            1547.1
# 29                  1                23.4             696            1362.6
# ..                ...                 ...             ...               ...
# 900                 4                75.6             391             887.7
# 901                11                27.6             476             846.9
# 902                19                59.0             297             509.0
# 903                20                45.6             202             905.1
# 904                 0                 0.0              57             745.8
# 905                26                43.2              90             652.8
# 906                10                79.0             183             885.4
# 907                 0                 0.0             176             798.3
# 908                17                32.4             554            1237.5
# 909                38               142.0            1099            1880.5
# 910                11                94.8             876            1693.5
# 911                 4                 9.0             624            1233.3
# 912                 3                 7.2             464            1203.3
# 913                25                47.4             705            1509.3
# 914                28               121.2             765            1511.7
# 915                 2                27.0             442            1332.6
# 916                 8                51.0             523            1247.4
# 917                 1                 7.8             580            1682.4
# 918                11                30.5             853            1729.1
# 919                22                62.4             442            1736.4
# 920                32                83.4             431            1482.3
# 921                 1                 9.0             322            1149.0
# 922                 5                45.5             180            1247.9
# 923                 8                44.4             645            2334.0
# 924                 5                15.0             140             552.9
# 925                27                59.4             127             628.2
# 926                12                25.8             357             650.7
# 927                25                67.0             596            1039.0
# 928                 0                 0.0             609            1188.3
# 929                37               109.8             367             957.0
#
# [930 rows x 15 columns]

# %%
df_custom.isnull().sum()
# Out:
# CHURN                 0
# CUSTOMER_ID           0
# GENDER                0
# AGE                   0
# CHARGE_TYPE           0
# HANDSET               0
# USAGE_BAND            0
# SERVICE_DURATION      0
# DROPPED_CALLS         0
# PEAK_CALLS_NO         0
# PEAK_CALLS_TIME       0
# WEEKEND_CALLS_NO      0
# WEEKEND_CALLS_TIME    0
# TOTAL_CALLS_NO        0
# TOTAL_CALLS_TIME      0
# dtype: int64

# %%
df_custom.drop("CUSTOMER_ID",axis=1,inplace = True)
df_custom.columns
# Out:
# Index(['CHURN', 'GENDER', 'AGE', 'CHARGE_TYPE', 'HANDSET', 'USAGE_BAND',
#        'SERVICE_DURATION', 'DROPPED_CALLS', 'PEAK_CALLS_NO', 'PEAK_CALLS_TIME',
#        'WEEKEND_CALLS_NO', 'WEEKEND_CALLS_TIME', 'TOTAL_CALLS_NO',
#        'TOTAL_CALLS_TIME'],
#       dtype='object')

# %%
df_custom_y = df_custom["CHURN"]
df_custom_x = pd.get_dummies(df_custom)
df_custom_x.drop("CHURN",axis= 1,inplace = True)
# df_custom_x_scale = scale(df_custom_x,axis=0)

# %%
x= df_custom_x
y= df_custom_y
x_tr,x_test,y_tr,y_test = train_test_split(x,y,test_size = 0.3,random_state = 1234)

print("train data x size : {}".format(x_tr.shape))
print("train data y size : {}".format(y_tr.shape))
print("test data x size : {}".format(x_test.shape))
print("test data y size : {}".format(y_test.shape))
# Out:
# train data x size : (651, 33)
# train data y size : (651,)
# test data x size : (279, 33)
# test data y size : (279,)

# %%
gb_uncustomized = GradientBoostingClassifier(random_state = 1234)
gb_uncustomized.fit(x_tr,y_tr)
print("Accuracy on training set:{:.3f}".format(gb_uncustomized.score(x_tr,y_tr)))
print("Accuracy on test set:{:.3f}".format(gb_uncustomized.score(x_test,y_test)))
# Out:
# Accuracy on training set:0.971
# Accuracy on test set:0.885

# %%
x_tr_scaled = scale(x_tr,axis = 0)
x_test_scaled = scale(x_test, axis = 0)

pd.DataFrame(x_tr_scaled, columns = x_tr.columns).head()
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by the scale function.
#   """Entry point for launching an IPython kernel.
# /home/pirl/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype uint8, int64, float64 were all converted to float64 by the scale function.
#         AGE  SERVICE_DURATION  DROPPED_CALLS  PEAK_CALLS_NO  PEAK_CALLS_TIME  \
# 0  0.659297          0.121772      -0.191707       1.476872         1.496854
# 1  0.736049          0.786591       2.396339      -0.661815        -0.534734
# 2 -0.415244          1.480625      -0.766829       1.432593         1.087469
# 3 -0.568749          1.178499      -0.191707       0.117500        -0.452149
# 4  0.045274          1.520528       2.108779      -0.431563        -0.870973
#
#    WEEKEND_CALLS_NO  WEEKEND_CALLS_TIME  TOTAL_CALLS_NO  TOTAL_CALLS_TIME  \
# 0         -0.518328            0.678178        1.575792          1.532985
# 1         -0.075671           -0.284308       -0.569331         -0.143503
# 2         -1.024223           -1.356793        0.979029          0.475336
# 3         -0.644802           -0.944298       -0.287078         -0.953914
# 4         -0.771276            1.745163       -0.750780         -0.956148
#
#    GENDER_F       ...         HANDSET_S80  HANDSET_SOP10  HANDSET_SOP20  \
# 0  0.915960       ...            -0.46075      -0.111542      -0.111542
# 1  0.915960       ...            -0.46075      -0.111542      -0.111542
# 2  0.915960       ...            -0.46075      -0.111542      -0.111542
# 3  0.915960       ...            -0.46075      -0.111542      -0.111542
# 4 -1.091751       ...            -0.46075      -0.111542      -0.111542
#
#    HANDSET_WC95  USAGE_BAND_High  USAGE_BAND_Low  USAGE_BAND_Med  \
# 0     -0.374306        -0.262613       -0.118401       -1.105370
# 1     -0.374306        -0.262613       -0.118401        0.904674
# 2     -0.374306        -0.262613       -0.118401       -1.105370
# 3      2.671610        -0.262613       -0.118401        0.904674
# 4     -0.374306        -0.262613       -0.118401        0.904674
#
#    USAGE_BAND_MedHigh  USAGE_BAND_MedLow  USAGE_BAND_None
# 0            1.788854          -0.390144        -0.039223
# 1           -0.559017          -0.390144        -0.039223
# 2            1.788854          -0.390144        -0.039223
# 3           -0.559017          -0.390144        -0.039223
# 4           -0.559017          -0.390144        -0.039223
#
# [5 rows x 33 columns]

# %%
gb_scaled = GradientBoostingClassifier(random_state = 1234)
gb_scaled.fit(x_tr_scaled,y_tr)

print("train 정확도: {:.3f}".format(gb_scaled.score(x_tr_scaled,y_tr)))
     
print("test 정확도: {:.3f}".format(gb_scaled.score(x_test_scaled,y_test)))
# Out:
# train 정확도: 0.971
# test 정확도: 0.910

# %%
train_accuracy = []
test_accuracy = []

for lr in range(1,100,5):
    gb1 = GradientBoostingClassifier(learning_rate = lr/100,random_state = 1234)
    gb1.fit(x_tr_scaled,y_tr)
    train_accuracy.append(gb1.score(x_tr_scaled,y_tr))
    test_accuracy.append(gb1.score(x_test_scaled,y_test))

df_accuracy1 = pd.DataFrame()
df_accuracy1["LearningRate"] = [lr/100 for lr in range(1,100,5)]
df_accuracy1["TrainAccuracy"] = train_accuracy
df_accuracy1["TestAccuracy"] = test_accuracy

# %%
df_accuracy1.round(3)
df_accuracy1.set_index("LearningRate",inplace = False).plot.line()

# %%
para_est = [est for est in range(50,150,10)]
lr = 0.2

train_accuracy = [];test_accuracy=[];
for ests in para_est:
    gb2 = GradientBoostingClassifier(learning_rate = 0.2, n_estimators = ests, random_state= 1234)
    gb2.fit(x_tr_scaled,y_tr)
    train_accuracy.append(gb2.score(x_tr_scaled,y_tr))
    test_accuracy.append(gb2.score(x_test_scaled,y_test))
    
df_accuracy2 = pd.DataFrame()
df_accuracy2["Estimators"] = para_est
df_accuracy2["TrainAccuracy"] = train_accuracy
df_accuracy2["TestAccuracy"] = test_accuracy

df_accuracy2
# Out:
#    Estimators  TrainAccuracy  TestAccuracy
# 0          50       0.970814      0.910394
# 1          60       0.978495      0.910394
# 2          70       0.984639      0.906810
# 3          80       0.992320      0.910394
# 4          90       0.996928      0.906810
# 5         100       0.998464      0.906810
# 6         110       0.998464      0.906810
# 7         120       1.000000      0.906810
# 8         130       1.000000      0.899642
# 9         140       1.000000      0.906810

# %%
df_accuracy2.set_index("Estimators",inplace= False).plot.line()

# %%
lr = 0.2;n_est = 100;
para_max_depth = [i+1 for i in range(5)]

train_accuracy = []; test_accuracy = [];

for depth in para_max_depth:
    gb3 = GradientBoostingClassifier(learning_rate= 0.2, n_estimators=n_est,max_depth = depth, random_state=1234)
    gb3.fit(x_tr_scaled,y_tr)
    
    train_accuracy.append(gb3.score(x_tr_scaled,y_tr))
    test_accuracy.append(gb3.score(x_test_scaled,y_test))

df_accuracy3 = pd.DataFrame()
df_accuracy3["MaxDepth"] = para_max_depth
df_accuracy3["TrainAccuracy"] = train_accuracy
df_accuracy3["TestAccuracy"] = test_accuracy
df_accuracy3.round(3)
# Out:
#    MaxDepth  TrainAccuracy  TestAccuracy
# 0         1          0.914         0.903
# 1         2          0.968         0.892
# 2         3          0.998         0.907
# 3         4          1.000         0.896
# 4         5          1.000         0.892

# %%
df_accuracy3.round(3)# depth =4 일때가 적당함

df_accuracy3.set_index("MaxDepth",inplace = False).plot.line()

# %%
lr = 0.2; n_est = 100; max_depth = 3;
para_min_leaf = [i+1 for i in range(10)]

train_accuracy = [];test_accuracy = [];

for leafsize in para_min_leaf:
    gb4 = GradientBoostingClassifier(learning_rate= lr,n_estimators=n_est , max_depth = max_depth, min_samples_leaf= leafsize, random_state= 1234)
    gb4.fit(x_tr_scaled,y_tr)
    train_accuracy.append(gb4.score(x_tr_scaled,y_tr))
    test_accuracy.append(gb4.score(x_test_scaled,y_test))

df_accuracy4 = pd.DataFrame()
df_accuracy4["MinLeafSize"] = para_min_leaf
df_accuracy4["TrainAccuracy"] = train_accuracy
df_accuracy4["TestAccuracy"] = test_accuracy

df_accuracy4.round(3)
df_accuracy4.set_index("MinLeafSize",inplace = False).plot.line()

# %%
gb_model = GradientBoostingClassifier(learning_rate= 0.1,max_depth = 4, min_samples_leaf=30,n_estimators=5,random_state=1234)

gb_model.fit(x_tr_scaled,y_tr)
# # 
# x_tr = pd.DataFrame(x_tr,columns=df_custom_x.columns)
df_feature_importance = pd.DataFrame()
# df_tr_scaled 와 df_tr의 columns는 같으므로 df형태의 df_tr을 쓴다.
df_feature_importance["feature"] = x_tr.columns
df_feature_importance["importance"] = gb_model.feature_importances_
df_feature_importance.sort_values(by = "importance",ascending = False).round(3)

def plot_feature_importances(model):
    n_features = x_tr_scaled.shape[1]
    plt.barh(range(n_features),model.feature_importances_,align="center")
    plt.yticks(np.arange(n_features),x_tr.columns)
    plt.xlabel("설명변수 중요도")
    plt.ylabel("설명변수")
    plt.ylim(-1,n_features)
    
plot_feature_importances(gb_model)
